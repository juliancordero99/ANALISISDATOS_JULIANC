# %%
#Julian Esteban Cordero Ramos - 202016908_48

# %%
# Cargar las librerias necesarias

import pandas as pd #Manejo y analisis de estructuras de datos
import numpy as np #Calculo numerico y analisis de datos
import seaborn as sns #Creacion de graficos estadísticos
import matplotlib.pyplot as plt #Creacino de graficos en dos dimensiones

# Librerías para implementar modelos de ciencia de datos

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import classification_report, confusion_matrix

# %%
#Lectura de datos en Python y lo cargamos en la variable Salud

Carro= pd.read_csv('C:/Users/julia/Documents/UNAD/8. OCTAVO SEMESTRE/ANALISIS DE DATOS/Tarea 3 - Algoritmos de Aprendizaje Supervisado/Anexo 2 - Dataset Vehicle/Carros.CSV')

# %%
#Realizamos la lectura de los datos para el analisis exploratorio
Carro.head(50)
# Out:
#                                                Nombre    Anio     precio  \
# 0                              Maruti Swift Dzire VDI  2014.0   450000.0
# 1                        Skoda Rapid 1.5 TDI Ambition  2014.0   370000.0
# 2   Honda City 2017-2020 EXi,2006,158000,140000,Pe...     NaN        NaN
# 3                           Hyundai i20 Sportz Diesel  2010.0   225000.0
# 4   Maruti Swift VXI BSIII,2007,130000,120000,Petr...     NaN        NaN
# 5                       Hyundai Xcent 1.2 VTVT E Plus  2017.0   440000.0
# 6   Maruti Wagon R LXI DUO BSIII,2007,96000,175000...     NaN        NaN
# 7                                  Maruti 800 DX BSII  2001.0    45000.0
# 8                                    Toyota Etios VXD  2011.0   350000.0
# 9                Ford Figo Diesel Celebration Edition  2013.0   200000.0
# 10                    Renault Duster 110PS Diesel RxL  2014.0   500000.0
# 11                                      Maruti Zen LX  2005.0    92000.0
# ...

# %%
#descripción de los datos
Carro.describe()
# Out:
#               Anio        precio  km_recorridos     asientos
# count  7787.000000  7.787000e+03   7.787000e+03  7566.000000
# mean   2014.054193  6.566975e+05   6.840663e+04     5.422284
# std       3.911379  8.174188e+05   5.663441e+04     0.955162
# min    1983.000000  2.999900e+04   1.000000e+00     2.000000
# 25%    2012.000000  2.750000e+05   3.300150e+04     5.000000
# 50%    2015.000000  4.599990e+05   6.000000e+04     5.000000
# 75%    2017.000000  6.965000e+05   9.000000e+04     5.000000
# max    2020.000000  1.000000e+07   2.360457e+06    14.000000

# %%
#Valores faltantes y atipicos.

plt.figure(figsize=(6,3))
sns.boxplot(x=Carro['Anio']) #Diagrama de cajas
plt.title('identificacion datos faltantes y atipicos',fontsize=10)
# Out:
# Text(0.5, 1.0, 'identificacion datos faltantes y atipicos')

# %%
#Valores faltantes y atipicos.

plt.figure(figsize=(6,3))
sns.boxplot(x=Carro['precio']) #Diagrama de cajas
plt.title('identificacion datos faltantes y atipicos',fontsize=10)
# Out:
# Text(0.5, 1.0, 'identificacion datos faltantes y atipicos')

# %%
#Valores faltantes y atipicos.

plt.figure(figsize=(6,3))
sns.boxplot(x=Carro['km_recorridos']) #Diagrama de cajas
plt.title('identificacion datos faltantes y atipicos',fontsize=10)
# Out:
# Text(0.5, 1.0, 'identificacion datos faltantes y atipicos')

# %%
#2 PROCESAR LOS DATOS LIMPIANDOLOS, TRATANDO VALORES FALTANTES Y TRANSFORMANDO SEGUN SEA NECESARIO

#Revision Datos faltantes

# Contar y mostrar los datos que contienen NaN en la columna "Anio"
Anio_NaN = Carro['Anio'].isna().sum()
print("Cantidad de registros con NaN en la columna 'Anio':", Anio_NaN)

# Mostrar los datos que contienen NaN en la columna "Anio"
datos_nan_anio = Carro[Carro['Anio'].isna()]
print("Datos con NaN en la columna 'Anio':")
print(datos_nan_anio)

# Contar y mostrar el conteo de NaN en la columna "km_recorridos"
km_recorridos_NaN = Carro['km_recorridos'].isna().sum()
print("Cantidad de registros con NaN en la columna 'km_recorridos':", km_recorridos_NaN)

# Contar y mostrar el conteo de NaN en la columna "motor"
motor_NaN = Carro['motor'].isna().sum()
print("Cantidad de registros con NaN en la columna 'motor':", motor_NaN)

# Contar y mostrar el conteo de NaN en la columna "potencia"
potencia_NaN = Carro['potencia'].isna().sum()
print("Cantidad de registros con NaN en la columna 'potencia':", potencia_NaN)
# Out:
# Cantidad de registros con NaN en la columna 'Anio': 341
# Datos con NaN en la columna 'Anio':
#                                                  Nombre  Anio  precio  \
# 2     Honda City 2017-2020 EXi,2006,158000,140000,Pe...   NaN     NaN
# 4     Maruti Swift VXI BSIII,2007,130000,120000,Petr...   NaN     NaN
# 6     Maruti Wagon R LXI DUO BSIII,2007,96000,175000...   NaN     NaN
# 226   Hyundai i20 1.2 Sportz,2012,275000,93000,Petro...   NaN     NaN
# 242   Hyundai Accent GLE,2007,80000,120000,Petrol,In...   NaN     NaN
# ...                                                 ...   ...     ...
# 8076  Maruti Wagon R LXI BSIII,2006,150000,50000,Pet...   NaN     NaN
# 8079  Tata Indigo LS,2007,90177,129000,Diesel,Indivi...   NaN     NaN
# 8082  Ford Fiesta 1.4 Duratorq EXI,2007,125000,11000...   NaN     NaN
# 8104  Honda City 2017-2020 VTEC,2006,160000,70000,Pe...   NaN     NaN
# 8124  Hyundai Verna CRDi SX,2007,135000,119000,Diese...   NaN     NaN
#
# ...

# %%
# Lista de columnas a verificar
columnas = ['Anio', 'km_recorridos', 'motor', 'potencia']

# Eliminar filas con NaN en cualquiera de las columnas especificadas
Carro = Carro.dropna(subset=columnas)

# Verificar que las filas con NaN se hayan eliminado
for columna in columnas:
    cantidad_nan = Carro[columna].isna().sum()
    print(f"Cantidad de registros con NaN en la columna '{columna}': {cantidad_nan}")
# Out:
# Cantidad de registros con NaN en la columna 'Anio': 0
# Cantidad de registros con NaN en la columna 'km_recorridos': 0
# Cantidad de registros con NaN en la columna 'motor': 0
# Cantidad de registros con NaN en la columna 'potencia': 0

# %%
#valido nuevamente con el codigo anterior

# Contar y mostrar los datos que contienen NaN en la columna "Anio"
Anio_NaN = Carro['Anio'].isna().sum()
print("Cantidad de registros con NaN en la columna 'Anio':", Anio_NaN)

# Mostrar los datos que contienen NaN en la columna "Anio"
datos_nan_anio = Carro[Carro['Anio'].isna()]
print("Datos con NaN en la columna 'Anio':")
print(datos_nan_anio)

# Contar y mostrar el conteo de NaN en la columna "km_recorridos"
km_recorridos_NaN = Carro['km_recorridos'].isna().sum()
print("Cantidad de registros con NaN en la columna 'km_recorridos':", km_recorridos_NaN)

# Contar y mostrar el conteo de NaN en la columna "motor"
motor_NaN = Carro['motor'].isna().sum()
print("Cantidad de registros con NaN en la columna 'motor':", motor_NaN)

# Contar y mostrar el conteo de NaN en la columna "potencia"
potencia_NaN = Carro['potencia'].isna().sum()
print("Cantidad de registros con NaN en la columna 'potencia':", potencia_NaN)
# Out:
# Cantidad de registros con NaN en la columna 'Anio': 0
# Datos con NaN en la columna 'Anio':
# Empty DataFrame
# Columns: [Nombre, Anio, precio, km_recorridos, combustible, vendedor, transmision, propietario, kilometraje, motor, potencia, torque, asientos]
# Index: []
# Cantidad de registros con NaN en la columna 'km_recorridos': 0
# Cantidad de registros con NaN en la columna 'motor': 0
# Cantidad de registros con NaN en la columna 'potencia': 0

# %%
#Revision del tipo de info y datos faltantes

Carro.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7566 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nombre         7566 non-null   object
#  1   Anio           7566 non-null   float64
#  2   precio         7566 non-null   float64
#  3   km_recorridos  7566 non-null   float64
#  4   combustible    7566 non-null   object
#  5   vendedor       7566 non-null   object
#  6   transmision    7566 non-null   object
#  7   propietario    7566 non-null   object
#  8   kilometraje    7566 non-null   object
#  9   motor          7566 non-null   object
#  10  potencia       7566 non-null   object
#  11  torque         7565 non-null   object
#  12  asientos       7566 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 827.5+ KB

# %%
#me faltó precio, procedo a hacer el mismo procedimiento
#valido cantidad de datos con NaN en columna precio
cantidad_nan_precio = Carro['precio'].isna().sum()
print("Cantidad de registros con NaN en la columna 'precio':", cantidad_nan_precio)
# Out:
# Cantidad de registros con NaN en la columna 'precio': 0

# %%
# Al eliminar los registros de las columnas anteriores, se infiere que se han eliminado aquellos con NaN en la columna precio

# %%
#3. Seleccionar las características más relevantes para entrenar el modelo utilizando selección de características. 

Carro['precio'].value_counts()
# Out:
# precio
# 300000.0     211
# 600000.0     210
# 550000.0     204
# 350000.0     197
# 450000.0     194
#             ...
# 654000.0       1
# 486000.0       1
# 1670000.0      1
# 7200000.0      1
# 746000.0       1
# Name: count, Length: 661, dtype: int64

# %%
Carro[['precio']].head(40)
# Out:
#        precio
# 0    450000.0
# 1    370000.0
# 3    225000.0
# 5    440000.0
# 7     45000.0
# 8    350000.0
# 9    200000.0
# 10   500000.0
# 11    92000.0
# 12   280000.0
# 14   180000.0
# 15   400000.0
# 16   778000.0
# 17   500000.0
# 18   150000.0
# 19   680000.0
# 20   174000.0
# 21   950000.0
# 22   525000.0
# 23   600000.0
# 24   500000.0
# 25   575000.0
# 26   275000.0
# 27   300000.0
# 28   220000.0
# 29   254999.0
# 30   670000.0
# 32   150000.0
# 33   730000.0
# 34   650000.0
# 35   330000.0
# 36   366000.0
# 37  1149000.0
# 38   150000.0
# 39   425000.0
# 40   150000.0
# 41  2100000.0
# 42   925000.0
# 43   425000.0
# 44   675000.0

# %%
#4. Dividir el dataset en Train y Test para evaluar correctamente el modelo. 
from sklearn.model_selection import train_test_split

# Dividir el conjunto de datos en 75% para entrenamiento y 25% para prueba
X = Carro.drop('precio', axis=1)  # Features
Y = Carro['precio']  # Target variable

# Dividir los datos
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25, random_state=42)

# Verificar las dimensiones de los conjuntos de datos divididos
print("Dimensiones del conjunto de entrenamiento:", X_train.shape)
print("Dimensiones del conjunto de prueba:", X_test.shape)
# Out:
# Dimensiones del conjunto de entrenamiento: (5674, 12)
# Dimensiones del conjunto de prueba: (1892, 12)

# %%
#Construir el modelo de regresion (((LINEAL)))

from sklearn.linear_model import LinearRegression

# Seleccionar solo las columnas 'precio' y 'km_recorridos' como características
X = Carro[['precio', 'km_recorridos']]

# Seleccionar la variable objetivo
Y = Carro['precio']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, Y_train, Y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Inicializar y ajustar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train, y_train)

# Hacer predicciones en el conjunto de prueba
predicciones = modelo_regresion.predict(X_test)

# %%
print (predicciones)
# Out:
# [5500000.  825000.  160000. ...  325000.  325000.  630000.]

# %%
# 6. Evaluar el desempeño del modelo en el conjunto de Test con métricas como precisión, recall, F1-score, etc. 
from sklearn.metrics import mean_squared_error, r2_score

# Calcular predicciones en el conjunto de prueba
predicciones = modelo_regresion.predict(X_test)

# Calcular el Error Cuadrático Medio (MSE)
mse = mean_squared_error(y_test, predicciones)
print("Error Cuadrático Medio (MSE):", mse)

# Calcular la Raíz del Error Cuadrático Medio (RMSE)
rmse = np.sqrt(mse)
print("Raíz del Error Cuadrático Medio (RMSE):", rmse)

# Calcular el Coeficiente de Determinación (R-cuadrado)
r2 = r2_score(y_test, predicciones)
print("Coeficiente de Determinación (R-cuadrado):", r2)
# Out:
# Error Cuadrático Medio (MSE): 1.5633902447244096e-19
# Raíz del Error Cuadrático Medio (RMSE): 3.953972995259843e-10
# Coeficiente de Determinación (R-cuadrado): 1.0

# %%
import matplotlib.pyplot as plt

# Crear un gráfico de dispersión de 'precio' vs 'km_recorridos'
plt.figure(figsize=(8, 6))
plt.scatter(Carro['km_recorridos'], Carro['precio'], alpha=0.5)
plt.title('Diagrama de Dispersión de Precio vs km_recorridos')
plt.xlabel('km_recorridos')
plt.ylabel('Precio')
plt.grid(True)
plt.show()

# %%
from sklearn.linear_model import LinearRegression


# Seleccionar solo las columnas 'precio' y 'anio' como características
X = Carro[['Anio']]
y = Carro['precio']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# Inicializar y ajustar el modelo de regresión lineal
modelo_regresion = LinearRegression()
modelo_regresion.fit(X_train, y_train)

# Hacer predicciones en el conjunto de prueba
predicciones = modelo_regresion.predict(X_test)

# %%
print (predicciones)
# Out:
# [1107483.38747334  834414.83019292  288277.71563214 ... -257859.39892867
#   561346.27291253 1198506.23990014]

# %%
import matplotlib.pyplot as plt

# Crear un gráfico de dispersión de 'precio' vs 'anio'
plt.figure(figsize=(8, 6))
plt.scatter(Carro['Anio'], Carro['precio'], alpha=0.5)
plt.title('Diagrama de Dispersión de Precio vs Año')
plt.xlabel('Año')
plt.ylabel('Precio')
plt.grid(True)
plt.show()
